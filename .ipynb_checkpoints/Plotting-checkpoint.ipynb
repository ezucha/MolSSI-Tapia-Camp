# %% [markdown]
# ## Plotting Lesson

# %%
pwd
# Out:
# 'C:\\Users\\Elora\\Desktop\\cms-workshop\\data'

# %%
import os

# %%
import numpy
distance_file = os.path.join('distance_data_headers.csv')
distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
headers = distances[0,:]
data = distances[1:,:]
data = data.astype(numpy.float)

# %%
print(headers)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
print(data)
# Out:
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [2.00000e+00 8.61810e+00 6.09420e+00 1.39594e+01 1.16945e+01]
#  [3.00000e+00 9.00660e+00 6.06370e+00 1.30924e+01 1.13043e+01]
#  ...
#  [9.99800e+03 8.66250e+00 7.73060e+00 9.54690e+00 1.03063e+01]
#  [9.99900e+03 9.24560e+00 7.88860e+00 9.81510e+00 1.07564e+01]
#  [1.00000e+04 8.81350e+00 7.91700e+00 9.95170e+00 1.07848e+01]]

# %%
import matplotlib.pyplot as plt #python library

# %%
sample = headers[1]
sample2 = headers[2]

plt.plot(data[:,1], label=sample) #names the sample
plt.plot(data[:,2], label=sample2)
plt.xlabel('Simulation Frame') #gives names to axis
plt.ylabel('Distance (angstrom)')
plt.legend()

plt.savefig('two_samples.png', dpi=300) #saves figure into file on computer #dpi sets high resolution

# %%
num_columns = len(headers)

print(headers)
print(F'The number of columns is {num_columns}')

for col in range(1, num_columns):
    plt.figure()
    print(F'The column number is {col}.')
    plt.plot(data[:,col], label=headers[col])
    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstrom)')
    plt.legend()
    plt.savefig(F'{headers[col]}.png', dpi=300)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']
# The number of columns is 5
# The column number is 1.
# The column number is 2.
# The column number is 3.
# The column number is 4.

# %%
plt.plot(data[:,0],data[:,1])

# %%
small_data = data[0:10:2, 0:3]
print(small_data)
# Out:
# [[1.     8.9542 5.8024]
#  [3.     9.0066 6.0637]
#  [5.     9.1294 5.9365]
#  [7.     8.8657 5.9186]
#  [9.     9.4184 6.1993]]

# %%
#slice data so that we get every 100 rows
#the syntax for slicing is start:stop:increment.
every_100 = data[0::100, 0:]
print(every_100)
# Out:
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [1.01000e+02 9.01390e+00 5.74360e+00 1.39145e+01 1.07853e+01]
#  [2.01000e+02 1.15060e+01 8.92650e+00 1.52785e+01 1.20995e+01]
#  [3.01000e+02 1.32053e+01 7.65060e+00 1.58632e+01 1.20482e+01]
#  [4.01000e+02 1.08274e+01 7.68970e+00 1.41698e+01 1.22827e+01]
#  [5.01000e+02 1.30953e+01 7.63540e+00 1.56024e+01 1.25670e+01]
#  [6.01000e+02 1.51074e+01 5.96740e+00 1.48006e+01 9.65620e+00]
#  [7.01000e+02 1.46342e+01 6.28470e+00 1.44311e+01 9.75210e+00]
#  [8.01000e+02 1.40266e+01 7.69970e+00 1.29560e+01 9.71980e+00]
#  [9.01000e+02 1.50463e+01 6.76670e+00 1.39174e+01 9.38670e+00]
#  [1.00100e+03 1.37788e+01 7.07980e+00 1.42761e+01 8.64640e+00]
#  [1.10100e+03 1.38250e+01 6.86480e+00 1.25745e+01 9.98030e+00]
#  [1.20100e+03 1.23739e+01 8.31870e+00 9.76060e+00 1.14267e+01]
#  [1.30100e+03 1.27814e+01 8.02930e+00 1.03307e+01 1.02243e+01]
#  [1.40100e+03 1.29724e+01 8.16050e+00 1.05845e+01 1.03510e+01]
# ...

# %%
plt.plot(every_100[:,0], every_100[:,1], '--')

# %%
plt.plot(every_100[:,0], every_100[:,1], 'o')

# %%
plt.plot(every_100[:,0], every_100[:,1], '--o')

# %%
plt.plot(every_100[:,0], every_100[:,1], '--or')

# %%
plt.plot(every_100[:,0], every_100[:,1], '-ob')

# %%
plt.plot(every_100[:,0], every_100[:,1], '--oy')
